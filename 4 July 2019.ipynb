# %% [markdown]
# ### Day Objectives
# - Data Visualisation using Matplotlib library
#     - Basic 2D plotting functions
#     - Plotting 2D graphs from csv Dataset
#         - Income Dataset
#         - AppStore dataset

# %%
# linear graph - 

import matplotlib.pyplot as plt

plt.title('Basic linear graph')
plt.plot([1,2,3],[1,2,3])
plt.show()

# %%
# Graph to plot distance and time

distance =list(range(2,11,2))
time=list(range(1,6))
#dist = 2 * time

plt.title('Distance vs Time')
plt.xlabel('Time')
plt.ylabel('Distance')
plt.plot(time,distance,'go')
plt.grid()
plt.show()

# %%
# Velocity = accele * Time
# v=a t
t = list(range(1,11))
a =list(range(1,len(t)+1))
v = [a[i] * i for i in range(len(t))]

plt.plot(t,v)
plt.grid()
plt.show()

# %%
n = list(range(10))
sqn = [i ** 3 for i in n]

plt.plot(n,sqn)
plt.show()

# %%
# sinsoidal Wave

# Voltage vs Time

import numpy as np

#t = [i/10 for i in range(1,21)]
t = np.arange(0.1, 2.0, 0.1)
v = [1 + np.sin(2*np.pi*i) for i in t] 
plt.title('time vs voltage')
plt.plot(t,v,'bo')
plt.grid()
plt.xlabel('Time')
plt.ylabel('Voltage')
plt.savefig('images/voltage-time.jpg')
plt.show()

# %%
# Income Dataset

# Plot income of Arkansas from 2005 - 2013
import pandas as pd
df = pd.read_csv('DataFiles/income.csv')
years = df.columns[2:]

incomeArkansas = df.values[3, 2:]

plt.title('Income of Arkansas')
plt.xlabel('year')
plt.ylabel('Income')
plt.plot(years,incomeArkansas)
plt.show()

# %%
# Income of all states rom 2005 - 2013
df
incomeallStates = []

for i in df.columns[2:]:
    incomeallStates.append(df[i].mean())
plt.plot(years, incomeallStates)
plt.title("Income of all sates")
plt.xlabel('year')
plt.ylabel('income')
plt.grid()
plt.show()
